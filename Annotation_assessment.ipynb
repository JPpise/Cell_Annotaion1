# %%
#The data contains the Cell id  of the sample given and the predictions done by the 3 Expert doctors--> where totally 12 types of cells are recognizes
#Build the model to check the disagreements of the preditions
#Give the approximate Statistics for Agreement by all the three experts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("C:\\Users\\Janaki\\annotation.csv")
dataset
# Out:
#       cell_id Dr. 123 Kid Dr. Do Little Dr. Scrubs
# 0     1000001       Type1         Type2      Type2
# 1     1000002       Type4         Type5      Type5
# 2     1000003       Type4         Type6      Type5
# 3     1000004       Type3         Type3      Type3
# 4     1000005       Type4         Type5      Type5
# 5     1000006       Type5         Type2      Type5
# 6     1000007       Type4         Type2      Type5
# 7     1000008       Type1         Type5      Type5
# 8     1000009       Type4         Type5      Type5
# 9     1000010       Type4         Type5      Type5
# 10    1000011       Type7         Type7      Type5
# 11    1000012       Type2         Type5        NaN
# 12    1000013       Type4         Type5      Type5
# 13    1000014       Type4         Type5      Type5
# 14    1000015       Type4         Type5      Type5
# 15    1000016       Type4         Type5      Type5
# 16    1000017       Type4         Type5      Type5
# ...

# %%
Pred_feature=["Dr. 123 Kid","Dr. Do Little","Dr. Scrubs"]
pred=dataset[Pred_feature]
pred
# Out:
#      Dr. 123 Kid Dr. Do Little Dr. Scrubs
# 0          Type1         Type2      Type2
# 1          Type4         Type5      Type5
# 2          Type4         Type6      Type5
# 3          Type3         Type3      Type3
# 4          Type4         Type5      Type5
# 5          Type5         Type2      Type5
# 6          Type4         Type2      Type5
# 7          Type1         Type5      Type5
# 8          Type4         Type5      Type5
# 9          Type4         Type5      Type5
# 10         Type7         Type7      Type5
# 11         Type2         Type5        NaN
# 12         Type4         Type5      Type5
# 13         Type4         Type5      Type5
# 14         Type4         Type5      Type5
# 15         Type4         Type5      Type5
# 16         Type4         Type5      Type5
# 17         Type1         Type2      Type5
# 18         Type4         Type5      Type5
# 19         Type4         Type5      Type5
# 20         Type4         Type5      Type5
# ...

# %%
pred.describe()
# Out:
#        Dr. 123 Kid Dr. Do Little Dr. Scrubs
# count         3998          3996       3998
# unique          12            12         11
# top          Type4         Type5      Type5
# freq          2671          2468       2824

# %%
pred["Dr. 123 Kid"].isnull().sum()
# Out:
# 1

# %%
pred["Dr. Do Little"].isnull().sum()
# Out:
# 3

# %%
pred["Dr. Scrubs"].isnull().sum()
# Out:
# 1
